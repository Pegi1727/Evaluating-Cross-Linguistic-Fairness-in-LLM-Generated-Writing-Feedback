# %% [markdown]
# # 01 Data Preprocessing
#
# This notebook loads the raw dataset, performs basic cleaning, and inspects the distributions of CEFR and L1 groups.

# %%
import pandas as pd
from pathlib import Path

DATA_PATH = Path("../data/Fairness_Raw_Data.csv")
df = pd.read_csv(DATA_PATH)
df.head()

# %%
df.info()

# %%
df.isna().sum()

# %%
df["CEFR"].value_counts().sort_index()

# %%
df["L1"].value_counts().sort_index()
